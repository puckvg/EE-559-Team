# %%
from src.dlc_practical_prologue import generate_pair_sets
from src.utils import load_class_data, load_target_data, load_all_data, print_param_count
from src.models import *
from src.trainer import Trainer
import matplotlib.pyplot as plt

# %%
dl_train_all, dl_val_all, dl_test_all = load_all_data(normalize=True)

# %%
# Train siamese network without aux loss and return digits only 

# Can use any network with ten output nodes here
le_net = LeNet()

nb_epochs = 25
n_cv = 10
train_accuracies = []
train_losses = []
validation_accuracies = []
test_accuracies = []

# %%
for i in range(n_cv):
    print('cv iter', i)
    siamese_le_net = Siamese(le_net, target=None, weight_aux=0.)
    trainer = Trainer(nb_epochs=nb_epochs)

    loss_train, acc_train, acc_val = trainer.fit(siamese_le_net, dl_train_all, dl_val_all, verbose=True)
    train_losses.append(loss_train)
    train_accuracies.append(acc_train)
    validation_accuracies.append(acc_val)
    acc_test = trainer.test(siamese_le_net, dl_test_all, test_verbose=True, return_acc=True)
    
    test_accuracies.append(acc_test)
# Out:
# cv iter 0
# # Epoch 1/25:	 loss=1.93	 loss_val=1.31	 acc_val=76.34
# # Epoch 2/25:	 loss=0.83	 loss_val=0.58	 acc_val=89.29
# # Epoch 3/25:	 loss=0.46	 loss_val=0.42	 acc_val=88.39
# # Epoch 4/25:	 loss=0.31	 loss_val=0.35	 acc_val=89.29
# # Epoch 5/25:	 loss=0.22	 loss_val=0.32	 acc_val=90.62
# # Epoch 6/25:	 loss=0.2	 loss_val=0.3	 acc_val=91.52
# # Epoch 7/25:	 loss=0.16	 loss_val=0.28	 acc_val=92.41
# # Epoch 8/25:	 loss=0.14	 loss_val=0.28	 acc_val=90.62
# # Epoch 9/25:	 loss=0.1	 loss_val=0.28	 acc_val=92.86
# # Epoch 10/25:	 loss=0.08	 loss_val=0.28	 acc_val=91.52
# # Epoch 11/25:	 loss=0.06	 loss_val=0.26	 acc_val=92.41
# # Epoch 12/25:	 loss=0.05	 loss_val=0.28	 acc_val=93.3
# # Epoch 13/25:	 loss=0.05	 loss_val=0.29	 acc_val=92.86
# # Epoch 14/25:	 loss=0.04	 loss_val=0.26	 acc_val=94.2
# # Epoch 15/25:	 loss=0.03	 loss_val=0.25	 acc_val=93.75
# # Epoch 16/25:	 loss=0.02	 loss_val=0.22	 acc_val=94.64
# # Epoch 17/25:	 loss=0.02	 loss_val=0.24	 acc_val=93.75
# # Epoch 18/25:	 loss=0.02	 loss_val=0.3	 acc_val=93.75
# # Epoch 19/25:	 loss=0.02	 loss_val=0.27	 acc_val=93.3
# # Epoch 20/25:	 loss=0.01	 loss_val=0.25	 acc_val=94.2
# # Epoch 21/25:	 loss=0.01	 loss_val=0.27	 acc_val=92.86
# # Epoch 22/25:	 loss=0.01	 loss_val=0.23	 acc_val=93.75
# # Epoch 23/25:	 loss=0.01	 loss_val=0.24	 acc_val=93.75
# # Epoch 24/25:	 loss=0.01	 loss_val=0.26	 acc_val=94.2
# # Epoch 25/25:	 loss=0.01	 loss_val=0.26	 acc_val=94.2
# loss_test=0.13	 acc_test=96.97
# cv iter 1
# # Epoch 1/25:	 loss=0.02	 loss_val=0.24	 acc_val=93.75
# # Epoch 2/25:	 loss=0.01	 loss_val=0.39	 acc_val=91.96
# # Epoch 3/25:	 loss=0.01	 loss_val=0.28	 acc_val=95.09
# # Epoch 4/25:	 loss=0.01	 loss_val=0.33	 acc_val=94.64
# # Epoch 5/25:	 loss=0.0	 loss_val=0.33	 acc_val=94.2
# # Epoch 6/25:	 loss=0.0	 loss_val=0.31	 acc_val=95.09
# # Epoch 7/25:	 loss=0.0	 loss_val=0.32	 acc_val=94.64
# # Epoch 8/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.2
# # Epoch 9/25:	 loss=0.0	 loss_val=0.3	 acc_val=95.09
# # Epoch 10/25:	 loss=0.0	 loss_val=0.32	 acc_val=94.64
# # Epoch 11/25:	 loss=0.0	 loss_val=0.33	 acc_val=94.2
# # Epoch 12/25:	 loss=0.0	 loss_val=0.31	 acc_val=94.64
# # Epoch 13/25:	 loss=0.0	 loss_val=0.32	 acc_val=94.64
# # Epoch 14/25:	 loss=0.0	 loss_val=0.31	 acc_val=95.09
# # Epoch 15/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.2
# # Epoch 16/25:	 loss=0.0	 loss_val=0.32	 acc_val=95.09
# # Epoch 17/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.64
# # Epoch 18/25:	 loss=0.0	 loss_val=0.33	 acc_val=94.64
# # Epoch 19/25:	 loss=0.0	 loss_val=0.33	 acc_val=94.64
# # Epoch 20/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.64
# # Epoch 21/25:	 loss=0.0	 loss_val=0.34	 acc_val=95.09
# # Epoch 22/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.64
# # Epoch 23/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.64
# # Epoch 24/25:	 loss=0.0	 loss_val=0.34	 acc_val=94.64
# # Epoch 25/25:	 loss=0.0	 loss_val=0.35	 acc_val=94.64
# loss_test=0.16	 acc_test=97.27
# cv iter 2
# # Epoch 1/25:	 loss=0.03	 loss_val=0.4	 acc_val=93.75
# # Epoch 2/25:	 loss=0.01	 loss_val=0.31	 acc_val=94.64
# # Epoch 3/25:	 loss=0.0	 loss_val=0.38	 acc_val=93.75
# # Epoch 4/25:	 loss=0.0	 loss_val=0.33	 acc_val=95.54
# # Epoch 5/25:	 loss=0.0	 loss_val=0.35	 acc_val=95.54
# # Epoch 6/25:	 loss=0.0	 loss_val=0.34	 acc_val=95.54
# # Epoch 7/25:	 loss=0.0	 loss_val=0.35	 acc_val=95.54
# # Epoch 8/25:	 loss=0.0	 loss_val=0.35	 acc_val=95.54
# # Epoch 9/25:	 loss=0.0	 loss_val=0.35	 acc_val=95.54
# # Epoch 10/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.54
# # Epoch 11/25:	 loss=0.0	 loss_val=0.35	 acc_val=95.54
# # Epoch 12/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.54
# # Epoch 13/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.54
# # Epoch 14/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.09
# # Epoch 15/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.09
# # Epoch 16/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# # Epoch 17/25:	 loss=0.0	 loss_val=0.37	 acc_val=95.09
# # Epoch 18/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# # Epoch 19/25:	 loss=0.0	 loss_val=0.36	 acc_val=95.54
# # Epoch 20/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# # Epoch 21/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# # Epoch 22/25:	 loss=0.0	 loss_val=0.37	 acc_val=95.09
# # Epoch 23/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# # Epoch 24/25:	 loss=0.0	 loss_val=0.37	 acc_val=95.09
# # Epoch 25/25:	 loss=0.0	 loss_val=0.37	 acc_val=94.64
# loss_test=0.16	 acc_test=97.46
# cv iter 3
# # Epoch 1/25:	 loss=0.01	 loss_val=0.52	 acc_val=94.64
# # Epoch 2/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.09
# # Epoch 3/25:	 loss=0.02	 loss_val=0.44	 acc_val=94.2
# # Epoch 4/25:	 loss=0.02	 loss_val=0.44	 acc_val=95.54
# # Epoch 5/25:	 loss=0.01	 loss_val=0.55	 acc_val=92.86
# # Epoch 6/25:	 loss=0.01	 loss_val=0.4	 acc_val=95.09
# # Epoch 7/25:	 loss=0.0	 loss_val=0.42	 acc_val=95.54
# # Epoch 8/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.09
# # Epoch 9/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.09
# # Epoch 10/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 11/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 12/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 13/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 14/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 15/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 16/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 17/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 18/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 19/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 20/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 21/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 22/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 23/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 24/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# # Epoch 25/25:	 loss=0.0	 loss_val=0.41	 acc_val=95.09
# loss_test=0.16	 acc_test=97.56
# cv iter 4
# # Epoch 1/25:	 loss=0.0	 loss_val=0.48	 acc_val=94.64
# # Epoch 2/25:	 loss=0.0	 loss_val=0.44	 acc_val=94.64
# # Epoch 3/25:	 loss=0.01	 loss_val=0.54	 acc_val=93.75
# # Epoch 4/25:	 loss=0.03	 loss_val=0.34	 acc_val=94.64
# # Epoch 5/25:	 loss=0.01	 loss_val=0.42	 acc_val=94.2
# # Epoch 6/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.09
# # Epoch 7/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.09
# # Epoch 8/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 9/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 10/25:	 loss=0.0	 loss_val=0.38	 acc_val=95.54
# # Epoch 11/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 12/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 13/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 14/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 15/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 16/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 17/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 18/25:	 loss=0.0	 loss_val=0.39	 acc_val=95.54
# # Epoch 19/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 20/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 21/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 22/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 23/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 24/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# # Epoch 25/25:	 loss=0.0	 loss_val=0.4	 acc_val=95.54
# loss_test=0.16	 acc_test=97.85
# cv iter 5
# # Epoch 1/25:	 loss=0.0	 loss_val=0.55	 acc_val=95.09
# # Epoch 2/25:	 loss=0.01	 loss_val=0.55	 acc_val=94.2
# # Epoch 3/25:	 loss=0.0	 loss_val=0.48	 acc_val=93.3
# # Epoch 4/25:	 loss=0.02	 loss_val=0.51	 acc_val=93.75
# # Epoch 5/25:	 loss=0.01	 loss_val=0.41	 acc_val=94.64
# # Epoch 6/25:	 loss=0.0	 loss_val=0.48	 acc_val=94.64
# # Epoch 7/25:	 loss=0.0	 loss_val=0.43	 acc_val=95.09
# # Epoch 8/25:	 loss=0.0	 loss_val=0.45	 acc_val=95.09
# # Epoch 9/25:	 loss=0.0	 loss_val=0.45	 acc_val=95.09
# # Epoch 10/25:	 loss=0.0	 loss_val=0.45	 acc_val=95.09
# # Epoch 11/25:	 loss=0.0	 loss_val=0.45	 acc_val=95.09
# # Epoch 12/25:	 loss=0.0	 loss_val=0.45	 acc_val=95.09
# # Epoch 13/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.09
# # Epoch 14/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.09
# # Epoch 15/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.09
# # Epoch 16/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.09
# # Epoch 17/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.09
# # Epoch 18/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 19/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 20/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 21/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 22/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 23/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 24/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# # Epoch 25/25:	 loss=0.0	 loss_val=0.46	 acc_val=95.54
# loss_test=0.18	 acc_test=98.05
# cv iter 6
# # Epoch 1/25:	 loss=0.0	 loss_val=0.39	 acc_val=94.2
# # Epoch 2/25:	 loss=0.0	 loss_val=0.47	 acc_val=95.09
# # Epoch 3/25:	 loss=0.0	 loss_val=0.53	 acc_val=94.64
# # Epoch 4/25:	 loss=0.01	 loss_val=0.4	 acc_val=95.54
# # Epoch 5/25:	 loss=0.01	 loss_val=0.43	 acc_val=95.09
# # Epoch 6/25:	 loss=0.0	 loss_val=0.54	 acc_val=95.54
# # Epoch 7/25:	 loss=0.0	 loss_val=0.52	 acc_val=95.54
# # Epoch 8/25:	 loss=0.0	 loss_val=0.56	 acc_val=95.54
# # Epoch 9/25:	 loss=0.0	 loss_val=0.54	 acc_val=95.54
# # Epoch 10/25:	 loss=0.0	 loss_val=0.54	 acc_val=95.54
# # Epoch 11/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 12/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 13/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 14/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 15/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 16/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 17/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 18/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 19/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 20/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 21/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 22/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 23/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 24/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# # Epoch 25/25:	 loss=0.0	 loss_val=0.53	 acc_val=95.54
# loss_test=0.2	 acc_test=97.56
# cv iter 7
# # Epoch 1/25:	 loss=0.0	 loss_val=0.65	 acc_val=94.64
# # Epoch 2/25:	 loss=0.01	 loss_val=0.59	 acc_val=95.09
# # Epoch 3/25:	 loss=0.03	 loss_val=0.51	 acc_val=95.09
# # Epoch 4/25:	 loss=0.01	 loss_val=0.72	 acc_val=94.2
# # Epoch 5/25:	 loss=0.0	 loss_val=0.61	 acc_val=94.64
# # Epoch 6/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.54
# # Epoch 7/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.54
# # Epoch 8/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.54
# # Epoch 9/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.54
# # Epoch 10/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.54
# # Epoch 11/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 12/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 13/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 14/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 15/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 16/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 17/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 18/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 19/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 20/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 21/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 22/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 23/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 24/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# # Epoch 25/25:	 loss=0.0	 loss_val=0.58	 acc_val=95.54
# loss_test=0.2	 acc_test=97.17
# cv iter 8
# # Epoch 1/25:	 loss=0.0	 loss_val=0.75	 acc_val=94.64
# # Epoch 2/25:	 loss=0.0	 loss_val=0.77	 acc_val=93.75
# # Epoch 3/25:	 loss=0.01	 loss_val=0.61	 acc_val=95.54
# # Epoch 4/25:	 loss=0.0	 loss_val=0.77	 acc_val=94.2
# # Epoch 5/25:	 loss=0.0	 loss_val=0.66	 acc_val=94.2
# # Epoch 6/25:	 loss=0.0	 loss_val=0.51	 acc_val=94.2
# # Epoch 7/25:	 loss=0.0	 loss_val=0.65	 acc_val=94.64
# # Epoch 8/25:	 loss=0.0	 loss_val=0.61	 acc_val=94.64
# # Epoch 9/25:	 loss=0.0	 loss_val=0.62	 acc_val=95.09
# # Epoch 10/25:	 loss=0.0	 loss_val=0.62	 acc_val=95.09
# # Epoch 11/25:	 loss=0.0	 loss_val=0.61	 acc_val=95.09
# # Epoch 12/25:	 loss=0.0	 loss_val=0.61	 acc_val=95.09
# # Epoch 13/25:	 loss=0.0	 loss_val=0.61	 acc_val=95.09
# # Epoch 14/25:	 loss=0.0	 loss_val=0.6	 acc_val=95.09
# # Epoch 15/25:	 loss=0.0	 loss_val=0.6	 acc_val=95.09
# # Epoch 16/25:	 loss=0.0	 loss_val=0.6	 acc_val=95.09
# # Epoch 17/25:	 loss=0.0	 loss_val=0.6	 acc_val=95.09
# # Epoch 18/25:	 loss=0.0	 loss_val=0.6	 acc_val=95.09
# # Epoch 19/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.09
# # Epoch 20/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.09
# # Epoch 21/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.09
# # Epoch 22/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.09
# # Epoch 23/25:	 loss=0.0	 loss_val=0.59	 acc_val=95.09
# # Epoch 24/25:	 loss=0.0	 loss_val=0.59	 acc_val=94.64
# # Epoch 25/25:	 loss=0.0	 loss_val=0.59	 acc_val=94.64
# loss_test=0.24	 acc_test=97.46
# cv iter 9
# # Epoch 1/25:	 loss=0.0	 loss_val=0.69	 acc_val=93.75
# # Epoch 2/25:	 loss=0.0	 loss_val=0.58	 acc_val=94.2
# # Epoch 3/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 4/25:	 loss=0.0	 loss_val=0.63	 acc_val=94.2
# # Epoch 5/25:	 loss=0.0	 loss_val=0.63	 acc_val=93.75
# # Epoch 6/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 7/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 8/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 9/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 10/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 11/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 12/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 13/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 14/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 15/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 16/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 17/25:	 loss=0.0	 loss_val=0.62	 acc_val=93.75
# # Epoch 18/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# # Epoch 19/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# # Epoch 20/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# # Epoch 21/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# # Epoch 22/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# # Epoch 23/25:	 loss=0.0	 loss_val=0.63	 acc_val=94.2
# # Epoch 24/25:	 loss=0.0	 loss_val=0.63	 acc_val=94.2
# # Epoch 25/25:	 loss=0.0	 loss_val=0.62	 acc_val=94.2
# loss_test=0.25	 acc_test=97.66

# %%
import numpy as np 
avg_test_acc = np.mean(test_accuracies)
print('avg test acc', avg_test_acc)
stdev_test_acc = np.std(test_accuracies)
print('stdev', stdev_test_acc)
# Out:
# avg test acc 97.501
# stdev 0.30061437091396603

# %%
train_losses = np.mean(np.array(train_losses), axis=0)
train_accuracies = np.mean(np.array(train_accuracies), axis=0)
validation_accuracies = np.mean(np.array(validation_accuracies), axis=0)

# %%
from src.utils import plot_training_epochs
plt = plot_training_epochs(nb_epochs, train_losses, train_accuracies, 
                          validation_accuracies)
